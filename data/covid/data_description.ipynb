# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('county_all.csv')

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.shape
# Out:
# (1451604, 44)

# %%
df.sample(10)
# Out:
#          Unnamed: 0  CTFIPS               CTNAME  STFIPS  \
# 65294         65295    5061        Howard County       5
# 718041       718042   29143    New Madrid County      29
# 1370746     1370747   53027  Grays Harbor County      53
# 1435952     1435953   55121   Trempealeau County      55
# 1404805     1404806   54097        Upshur County      54
# 137853       137854    8107         Routt County       8
# 651354       651355   28017     Chickasaw County      28
# 1372217     1372218   53035        Kitsap County      53
# 1223453     1223454   48251       Johnson County      48
# 1140264     1140265   47081       Hickman County      47
#
#          Social.distancing.index  X..staying.home  Trips.person  \
# 65294                         11               12          3.82
# 718041                        18               20          3.37
# 1370746                       23               22          4.24
# 1435952                       10               13          3.71
# ...

# %%
df['date'].describe()
# Out:
# <ipython-input-6-07e98f8ab9f6>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df['date'].describe()
# count                 1451604
# unique                    462
# top       2021-03-07 00:00:00
# freq                     3142
# first     2020-01-01 00:00:00
# last      2021-04-06 00:00:00
# Name: date, dtype: object

# %%
df['date'].min(), df['date'].max()
# Out:
# (Timestamp('2020-01-01 00:00:00'), Timestamp('2021-04-06 00:00:00'))

# %%
df['CTFIPS'].nunique()
# Out:
# 3142

# %%
df.shape
# Out:
# (1451604, 44)

# %%
df['STFIPS'].nunique()
# Out:
# 51
